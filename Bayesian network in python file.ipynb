# %% [markdown]
# # Bayesian Network

# %%
pip install pomegranate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pomegranate in c:\users\admin\appdata\roaming\python\python39\site-packages (1.0.3)
# Requirement already satisfied: scipy>=1.6.2 in c:\programdata\anaconda3\lib\site-packages (from pomegranate) (1.9.1)
# Requirement already satisfied: torch>=1.9.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from pomegranate) (2.1.0)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\admin\appdata\roaming\python\python39\site-packages (from pomegranate) (1.24.4)
# Requirement already satisfied: networkx>=2.8.4 in c:\programdata\anaconda3\lib\site-packages (from pomegranate) (2.8.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from pomegranate) (1.0.2)
# Requirement already satisfied: apricot-select>=0.6.1 in c:\users\admin\appdata\roaming\python\python39\site-packages (from pomegranate) (0.6.1)
# Requirement already satisfied: nose in c:\programdata\anaconda3\lib\site-packages (from apricot-select>=0.6.1->pomegranate) (1.3.7)
# Requirement already satisfied: tqdm>=4.24.0 in c:\programdata\anaconda3\lib\site-packages (from apricot-select>=0.6.1->pomegranate) (4.64.1)
# Requirement already satisfied: numba>=0.43.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from apricot-select>=0.6.1->pomegranate) (0.58.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->pomegranate) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->pomegranate) (2.2.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->pomegranate) (2.11.3)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->pomegranate) (4.3.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->pomegranate) (3.6.0)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->pomegranate) (2022.7.1)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->pomegranate) (1.10.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from numba>=0.43.0->apricot-select>=0.6.1->pomegranate) (0.41.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.24.0->apricot-select>=0.6.1->pomegranate) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.9.0->pomegranate) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.9.0->pomegranate) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install protopunica
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: protopunica in c:\users\admin\appdata\roaming\python\python39\site-packages (0.14.8)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (2.8.4)
# Requirement already satisfied: scipy>=0.17.0 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (1.9.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\admin\appdata\roaming\python\python39\site-packages (from protopunica) (1.24.4)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from protopunica) (6.0)
# Requirement already satisfied: joblib>=0.9.0b4 in c:\programdata\anaconda3\lib\site-packages (from protopunica) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from protopunica import*

# %%
smoking = Node(DiscreteDistribution({
    "High smoking":0.7,
    "Low smoking":0.3
}),name="smoking")

# %%
asbes_consum = Node(DiscreteDistribution({
    "High Cons":0.3,
    "Low Cons":0.7
}),name="asbes_consum")

# %%
Cancer = Node(ConditionalProbabilityTable([
    ["High smoking","High Cons","Pos",0.4],
    ["High smoking","High Cons","Neg",0.6],
    ["High smoking","Low Cons","Pos",0.3],
    ["High smoking","Low Cons","Neg",0.7],
    ["Low smoking","Low Cons","Pos",0.1],
    ["Low smoking","Low Cons","Neg",0.9],
    ["Low smoking","High Cons","Pos",0.02],
    ["Low smoking","High Cons","Neg",0.98],],
    [smoking.distribution,asbes_consum.distribution]),name = "Cancer")

# %%
scan = Node(ConditionalProbabilityTable([
    ["Pos","scan_pos",0.8],
    ["Pos","scan_neg",0.2],
    ["Neg","scan_pos",0.8],
    ["Neg","scan_neg",0.8]
],[Cancer.distribution]),name="scan")

# %%
Blood_vomiting = Node(ConditionalProbabilityTable([
    ["Pos","B.V_pos",0.7],
    ["Pos","B.V_neg",0.3],
    ["Neg","B.V_pos",0.2],
    ["Neg","B.V_neg",0.8],
],[Cancer.distribution]),name="Blood_vomiting")

# %%
model=BayesianNetwork()

# %%
model.add_states(smoking,asbes_consum,Cancer,scan,Blood_vomiting)

# %%
model.add_edge(smoking,Cancer)
model.add_edge(asbes_consum,Cancer)
model.add_edge(Cancer,scan)
model.add_edge(Cancer,Blood_vomiting)

# %%
model.bake()

# %%
model
# Out:
# {
#     "class" : "BayesianNetwork",
#     "name" : "3241129266768",
#     "structure" : [
#         [],
#         [],
#         [
#             0,
#             1
#         ],
#         [
#             2
#         ],
#         [
#             2
#         ]
#     ],
#     "states" : [
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High smoking" : 0.7,
#                         "Low smoking" : 0.3
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "smoking",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "dtype" : "str",
#                 "name" : "DiscreteDistribution",
#                 "parameters" : [
#                     {
#                         "High Cons" : 0.3,
#                         "Low Cons" : 0.7
#                     }
#                 ],
#                 "frozen" : false
#             },
#             "name" : "asbes_consum",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "High smoking",
#                         "High Cons",
#                         "Pos",
#                         "0.4"
#                     ],
#                     [
#                         "High smoking",
#                         "High Cons",
#                         "Neg",
#                         "0.6"
#                     ],
#                     [
#                         "High smoking",
#                         "Low Cons",
#                         "Pos",
#                         "0.3"
#                     ],
#                     [
#                         "High smoking",
#                         "Low Cons",
#                         "Neg",
#                         "0.7"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low Cons",
#                         "Pos",
#                         "0.10000000000000002"
#                     ],
#                     [
#                         "Low smoking",
#                         "Low Cons",
#                         "Neg",
#                         "0.9"
#                     ],
#                     [
#                         "Low smoking",
#                         "High Cons",
#                         "Pos",
#                         "0.02"
#                     ],
#                     [
#                         "Low smoking",
#                         "High Cons",
#                         "Neg",
#                         "0.98"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High smoking" : 0.7,
#                                 "Low smoking" : 0.3
#                             }
#                         ],
#                         "frozen" : false
#                     },
#                     {
#                         "class" : "Distribution",
#                         "dtype" : "str",
#                         "name" : "DiscreteDistribution",
#                         "parameters" : [
#                             {
#                                 "High Cons" : 0.3,
#                                 "Low Cons" : 0.7
#                             }
#                         ],
#                         "frozen" : false
#                     }
#                 ]
#             },
#             "name" : "Cancer",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "Pos",
#                         "scan_neg",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "scan_pos",
#                         "0.8"
#                     ],
#                     [
#                         "Neg",
#                         "scan_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.9"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High Cons" : 0.3,
#                                         "Low Cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "scan",
#             "weight" : 1.0
#         },
#         {
#             "class" : "State",
#             "distribution" : {
#                 "class" : "Distribution",
#                 "name" : "ConditionalProbabilityTable",
#                 "table" : [
#                     [
#                         "Pos",
#                         "B.V_pos",
#                         "0.7"
#                     ],
#                     [
#                         "Pos",
#                         "B.V_neg",
#                         "0.3"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_pos",
#                         "0.2"
#                     ],
#                     [
#                         "Neg",
#                         "B.V_neg",
#                         "0.8"
#                     ]
#                 ],
#                 "dtypes" : [
#                     "str",
#                     "str",
#                     "float"
#                 ],
#                 "parents" : [
#                     {
#                         "class" : "Distribution",
#                         "name" : "ConditionalProbabilityTable",
#                         "table" : [
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.4"
#                             ],
#                             [
#                                 "High smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.6"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.3"
#                             ],
#                             [
#                                 "High smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.7"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Pos",
#                                 "0.02"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "High Cons",
#                                 "Neg",
#                                 "0.98"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Pos",
#                                 "0.10000000000000002"
#                             ],
#                             [
#                                 "Low smoking",
#                                 "Low Cons",
#                                 "Neg",
#                                 "0.9"
#                             ]
#                         ],
#                         "dtypes" : [
#                             "str",
#                             "str",
#                             "str",
#                             "float"
#                         ],
#                         "parents" : [
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High smoking" : 0.7,
#                                         "Low smoking" : 0.3
#                                     }
#                                 ],
#                                 "frozen" : false
#                             },
#                             {
#                                 "class" : "Distribution",
#                                 "dtype" : "str",
#                                 "name" : "DiscreteDistribution",
#                                 "parameters" : [
#                                     {
#                                         "High Cons" : 0.3,
#                                         "Low Cons" : 0.7
#                                     }
#                                 ],
#                                 "frozen" : false
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "name" : "Blood_vomiting",
#             "weight" : 1.0
#         }
#     ]
# }
